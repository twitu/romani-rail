# %%
from collections import defaultdict

class Station:
    code_mapping = {}
    train_mapping = defaultdict(list)

    def __init__(self, code, name):
        self.code = code
        self.name = name

        Station.code_mapping[code] = self

        # Special case for shivaji terminus
        if code == "CSMT":
            Station.code_mapping["CSTM"] = self
            
    def __str__(self):
        return f"{self.code}: {self.name}"

# %%
class Train:
    mapping = {}

    def __init__(self, number, name, src: Station, dst: Station):
        self.number = number
        self.name = name
        self.src = src
        self.dst = dst
        self.stops = []
        Train.mapping[number] = self

    def add_stop(self, time, code):
        station = Station.code_mapping[code]
        Station.train_mapping[code].append(self)
        self.stops.append((time, station))

    def __str__(self):
        return f"Train {self.name} ({self.name}): {self.src} -> {self.dst} with {self.stops.__len__()} stops"

# %%
import pandas as pd

railway_data = pd.read_csv("./train_details_2017.csv")
railway_data = railway_data.dropna()
# Out:
# /tmp/ipykernel_109846/4281938988.py:3: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   railway_data = pd.read_csv("./train_details_2017.csv")

# %%
# Index stations
for index, row in railway_data.iterrows():
    station_code = row["Station Code"]
    station_name = row["Station Name"]

    # Create a Station object if it doesn't exist yet
    if station_code not in Station.code_mapping:
        Station(station_code, station_name)

# %%
# Index trains
for index, row in railway_data.iterrows():
    num = row["Train No"]
    name = row["Train Name"]

    train = None
    if num not in Train.mapping:
        src = Station.code_mapping[row["Source Station"]]
        dst = Station.code_mapping[row["Destination Station"]]
        train = Train(num, name, src, dst)
    else:
        train = Train.mapping[num]

    seq = row["SEQ"]
    if seq == 1:
        # add first stop with departure time
        time = row["Departure Time"]
        station = row["Station Code"]
        train.add_stop(time, station)
    else:
        # add other stops with arrival time
        time = row["Arrival time"]
        station = row["Station Code"]
        train.add_stop(time, station)

# %%
from datetime import timedelta
from datetime import datetime

def update_time(data):
    for i, val in enumerate(data):
        dt = datetime.strptime(val, '%H:%M:%S')
        if i > 0 and dt < prev_dt:
            days_diff = (prev_dt - dt).days + 1
            dt += timedelta(days=days_diff)
        data[i] = dt
        prev_dt = dt

data = ['21:46:00', '22:27:00', '23:51:00', '01:00:00', '01:30:00']
update_time(data)
print(data)
# Out:
# [datetime.datetime(1900, 1, 1, 21, 46), datetime.datetime(1900, 1, 1, 22, 27), datetime.datetime(1900, 1, 1, 23, 51), datetime.datetime(1900, 1, 2, 1, 0), datetime.datetime(1900, 1, 2, 1, 30)]

# %%
dt = datetime(1900, 1, 1, 21, 46)
dt.strftime("%H:%M:%S")
# Out:
# '21:46:00'

# %%
# Increment station times with additional 24 hrs where it crosses a day
for train in Train.mapping.values():
    times = [tup[0] for tup in train.stops]
    stops = [tup[1] for tup in train.stops]
    update_time(times)
    train.stops = list(zip(times, stops))

# %%
def query_night_sleeper_train_from_station(station_code):
    station = Station.code_mapping[station_code]
    trains = Station.train_mapping[station_code]

    return [(train, query_night_sleeper_train_destinations(train, station)) for train in trains if (query_night_sleeper_train(train, station))]

def query_night_sleeper_train(train: Train, station: Station) -> bool:
    # check that train starts from source station between 7pm-2am
    for (time, stop_station) in train.stops:
        if stop_station == station:
            time_string = time.strftime("%H:%M:%S")
            if ("19:00:00" <= time_string <= "23:59:59") or ("00:00:00" <= time_string <= "02:00:00"):
                return True
            
    return False

def query_night_sleeper_train_destinations(train: Train, station: Station) -> list[Station]:
    start_time = None
    for (time, stop_station) in train.stops:
        if stop_station == station:
            start_time = time

    stations = []
    lower = timedelta(hours=6)
    upper = timedelta(hours=12)
    for (time, stop_station) in train.stops:
        if time > start_time:
            if lower <= time - start_time <= upper:
                stations.append(stop_station)
            
    return stations

data = query_night_sleeper_train_from_station("HWH")
print(len(data))
for (train, dests) in data:
    print(f"Train: {train}")
    for dest in dests:
        print(f"{dest}")
# Out:
# 171
# Train: Train TVC-SCL SPL (TVC-SCL SPL): TVC: TRIVANDRUM C -> SCL: SILCHAR with 58 stops
# MLDT: MALDA TOWN
# KNE: KISHANGANJ
# NJP: NEW JALPAIGU
# DQG: DHUPGURI
# Train: Train RNC HWH SHAT (RNC HWH SHAT): RNC: RANCHI -> HWH: HOWRAH JN. with 10 stops
# Train: Train BARABIL-HOWR (BARABIL-HOWR): BBN: BARBIL -> HWH: HOWRAH JN. with 11 stops
# Train: Train JNANESWARISU (JNANESWARISU): HWH: HOWRAH JN. -> LTT: LOKMANYA TIL with 17 stops
# ROU: ROURKELA
# JSG: JHARSUGUDA J
# BSP: BILASPUR JN.
# Train: Train HOWRAH PUNE (HOWRAH PUNE): HWH: HOWRAH JN. -> PUNE: PUNE JN. with 30 stops
# ROU: ROURKELA
# JSG: JHARSUGUDA J
# BRJN: BRAJARAJNAGA
# RIG: RAIGARH
# CPH: CHAMPA JN.
# BSP: BILASPUR JN.
# Train: Train HWH-LTT SAMR (HWH-LTT SAMR): HWH: HOWRAH JN. -> LTT: LOKMANYA TIL with 23 stops
# CKP: CHAKARADHARP
# ROU: ROURKELA
# JSG: JHARSUGUDA J
# RIG: RAIGARH
# Train: Train PA-HWH DURAN (PA-HWH DURAN): PUNE: PUNE JN. -> HWH: HOWRAH JN. with 8 stops
# Train: Train YPR-BGP ANGA (YPR-BGP ANGA): YPR: YESVANTPUR J -> BGP: BHAGALPUR with 29 stops
# KIUL: KIUL JN.
# AHA: ABHAIPUR
# JMP: JAMALPUR JN.
# BGP: BHAGALPUR
# Train: Train BGP-YPR ANGA (BGP-YPR ANGA): BGP: BHAGALPUR -> YPR: YESVANTPUR J with 29 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BAM: BERHAMPUR
# Train: Train CSMT-HWH DUR (CSMT-HWH DUR): CSMT: CST-MUMBAI -> HWH: HOWRAH JN. with 7 stops
# Train: Train HWH-JU EXP (HWH-JU EXP): HWH: HOWRAH JN. -> JU: JODHPUR JN. with 28 stops
# GAYA: GAYA JN.
# AUBR: ANUGRAH NARA
# DOS: DEHRI-ON-SON
# SSM: SASARAM
# BBU: BHABUA ROAD
# MGS: MUGHAL SARAI
# MZP: MIRZAPUR
# Train: Train HWH DLIKLK M (HWH DLIKLK M): HWH: HOWRAH JN. -> KLK: KALKA with 39 stops
# GAYA: GAYA JN.
# DOS: DEHRI-ON-SON
# SSM: SASARAM
# BBU: BHABUA ROAD
# MGS: MUGHAL SARAI
# MZP: MIRZAPUR
# Train: Train HWH MUMBAI M (HWH MUMBAI M): HWH: HOWRAH JN. -> CSMT: CST-MUMBAI with 48 stops
# KQR: KODERMA
# GAYA: GAYA JN.
# AUBR: ANUGRAH NARA
# DOS: DEHRI-ON-SON
# SSM: SASARAM
# BBU: BHABUA ROAD
# MGS: MUGHAL SARAI
# CAR: CHUNAR JN.
# MZP: MIRZAPUR
# BDL: VINDHYACHAL
# Train: Train HIMGIRI EXPR (HIMGIRI EXPR): HWH: HOWRAH JN. -> JAT: JAMMU TAWI with 32 stops
# JAJ: JHAJHA
# JMU: JAMUI
# KIUL: KIUL JN.
# MKA: MOKAMA JN.
# BKP: BAKHTIYARPUR
# PNC: PATNA SAHEB
# PNBE: PATNA JN.
# DNR: DANAPUR
# ARA: ARA
# BXR: BUXAR
# Train: Train VIBHUTI EXPR (VIBHUTI EXPR): HWH: HOWRAH JN. -> ALY: ALLAHABAD CI with 31 stops
# MKA: MOKAMA JN.
# BARH: BARH
# BKP: BAKHTIYARPUR
# FUT: FATUHA
# PNC: PATNA SAHEB
# PNBE: PATNA JN.
# DNR: DANAPUR
# BTA: BIHTA
# ARA: ARA
# BEA: BIHIYA
# RPR: RAGHUNATHPUR
# DURE: DUMRAON
# BXR: BUXAR
# GMR: GAHMAR
# DLN: DILDARNAGAR
# ZNA: ZAMANIA
# Train: Train RPH HWH EXP (RPH HWH EXP): RPH: RAMPUR HAT -> HWH: HOWRAH JN. with 9 stops
# Train: Train DANAPUR EXPR (DANAPUR EXPR): HWH: HOWRAH JN. -> RJPB: RAJENDRANAGA with 23 stops
# JMU: JAMUI
# MNP: MANANPUR
# BSQP: BANSIPUR
# KIUL: KIUL JN.
# LKR: LUCKEESARAI
# BRYA: BARHIYA
# HTZ: HATHIDAH JN
# MKA: MOKAMA JN.
# BARH: BARH
# BKP: BAKHTIYARPUR
# KOO: KHUSROPUR
# FUT: FATUHA
# PNC: PATNA SAHEB
# RJPB: RAJENDRANAGA
# Train: Train SCL - TVC EX (SCL - TVC EX): SCL: SILCHAR -> TVC: TRIVANDRUM C with 56 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# PSA: PALASA
# Train: Train GHY-SBC EXP (GHY-SBC EXP): GHY: GUWAHATI -> BNC: BANGALORE CA with 41 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# PSA: PALASA
# Train: Train GHY - SC EXP (GHY - SC EXP): GHY: GUWAHATI -> SC: SECUNDERABAD with 30 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# PSA: PALASA
# Train: Train SCL -TVC EXP (SCL -TVC EXP): SCL: SILCHAR -> TVC: TRIVANDRUM C with 56 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# PSA: PALASA
# Train: Train HWH-SC FALAK (HWH-SC FALAK): HWH: HOWRAH JN. -> SC: SECUNDERABAD with 26 stops
# KGP: KHARAGPUR
# BLS: BALASORE
# BHC: BHADRAKH
# Train: Train HWH CSMT MAI (HWH CSMT MAI): HWH: HOWRAH JN. -> CSMT: CST-MUMBAI with 42 stops
# JSG: JHARSUGUDA J
# BRJN: BRAJARAJNAGA
# RIG: RAIGARH
# KHS: KHARSIA
# SKT: SAKTI
# CPH: CHAMPA JN.
# BSP: BILASPUR JN.
# BYT: BHATAPARA
# Train: Train PURI-BBS-HWH (PURI-BBS-HWH): PURI: PURI -> HWH: HOWRAH JN. with 16 stops
# Train: Train HOWRAH-AHMED (HOWRAH-AHMED): HWH: HOWRAH JN. -> ADI: AHMEDABAD with 64 stops
# ROU: ROURKELA
# GP: RAJGANGPUR
# BMB: BAMRA
# JSG: JHARSUGUDA J
# BRJN: BRAJARAJNAGA
# BPH: BELPAHAR
# RIG: RAIGARH
# KHS: KHARSIA
# BUA: BARADWAR
# CPH: CHAMPA JN.
# NIA: NAILA
# AKT: AKALTARA
# BSP: BILASPUR JN.
# Train: Train HOWRAH-PURI (HOWRAH-PURI): HWH: HOWRAH JN. -> PURI: PURI with 14 stops
# MCS: MANCHESWAR
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# KASR: KANAS ROAD
# DEG: DELANG
# SIL: SAKHIGOPAL
# PURI: PURI
# Train: Train HWH-MAS MAIL (HWH-MAS MAIL): HWH: HOWRAH JN. -> MAS: CHENNAI CENT with 35 stops
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# CAP: CHATRAPUR
# BAM: BERHAMPUR
# IPM: ICHCHA PURAM
# SPT: SOMPETA
# PSA: PALASA
# NWP: NAUPADA JN.
# CHE: SRIKAKULAM R
# Train: Train HOWRAH YESVA (HOWRAH YESVA): HWH: HOWRAH JN. -> YPR: YESVANTPUR J with 35 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# PSA: PALASA
# CHE: SRIKAKULAM R
# Train: Train PRR-HWH LALM (PRR-HWH LALM): PRR: PURULIA JN. -> HWH: HOWRAH JN. with 9 stops
# Train: Train HWH-PDY WEEK (HWH-PDY WEEK): HWH: HOWRAH JN. -> PDY: PONDICHERRY with 17 stops
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# Train: Train PDY-HWH WKY (PDY-HWH WKY): PDY: PONDICHERRY -> HWH: HOWRAH JN. with 16 stops
# Train: Train CSMT-HWH WEE (CSMT-HWH WEE): CSMT: CST-MUMBAI -> HWH: HOWRAH JN. with 20 stops
# Train: Train HWH-PURI GAR (HWH-PURI GAR): HWH: HOWRAH JN. -> PURI: PURI with 9 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# PURI: PURI
# Train: Train PURULIA HWH (PURULIA HWH): PRR: PURULIA JN. -> HWH: HOWRAH JN. with 13 stops
# Train: Train HWH-PURI S/F (HWH-PURI S/F): HWH: HOWRAH JN. -> PURI: PURI with 10 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# SIL: SAKHIGOPAL
# PURI: PURI
# Train: Train HWH-PURI WEE (HWH-PURI WEE): HWH: HOWRAH JN. -> PURI: PURI with 10 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# SIL: SAKHIGOPAL
# PURI: PURI
# Train: Train HWH PBR  OKH (HWH PBR  OKH): HWH: HOWRAH JN. -> PBR: PORBANDAR with 30 stops
# ROU: ROURKELA
# JSG: JHARSUGUDA J
# RIG: RAIGARH
# CPH: CHAMPA JN.
# BSP: BILASPUR JN.
# BYT: BHATAPARA
# Train: Train GARBHA EXPRE (GARBHA EXPRE): HWH: HOWRAH JN. -> GIMB: GANDHIDHAM J with 17 stops
# GAYA: GAYA JN.
# SSM: SASARAM
# MGS: MUGHAL SARAI
# Train: Train AMRITSAR MAI (AMRITSAR MAI): HWH: HOWRAH JN. -> ASR: AMRITSAR JN. with 57 stops
# KIUL: KIUL JN.
# MKA: MOKAMA JN.
# BKP: BAKHTIYARPUR
# PNC: PATNA SAHEB
# PNBE: PATNA JN.
# DNR: DANAPUR
# ARA: ARA
# DURE: DUMRAON
# BXR: BUXAR
# GMR: GAHMAR
# DLN: DILDARNAGAR
# ZNA: ZAMANIA
# Train: Train U A TOOFAN E (U A TOOFAN E): SGNR: SHRI GANGANA -> HWH: HOWRAH JN. with 108 stops
# Train: Train DOON EXPRESS (DOON EXPRESS): HWH: HOWRAH JN. -> DDN: DEHRA DUN with 77 stops
# HZD: HAZARIBAGH R
# PSB: PARSABAD
# KQR: KODERMA
# PRP: PAHARPUR
# TKN: TANKUPPA
# GAYA: GAYA JN.
# GRRU: GURARU
# RFJ: RAFIGANJ
# JHN: JAKHIM
# PES: PHESAR
# AUBR: ANUGRAH NARA
# SEB: SON NAGAR JN
# DOS: DEHRI-ON-SON
# SSM: SASARAM
# KTQ: KUDRA
# BBU: BHABUA ROAD
# DGO: DURGAUTI
# KMS: KARAMNASA
# SYJ: SAIDRAJA
# CDMR: CHANDAULI MA
# Train: Train GANADEVTA EX (GANADEVTA EX): AZ: AZIMGANJ JN. -> HWH: HOWRAH JN. with 15 stops
# Train: Train BAGH EXPRESS (BAGH EXPRESS): HWH: HOWRAH JN. -> KGM: KATHGODAM with 66 stops
# JAJ: JHAJHA
# JMU: JAMUI
# KIUL: KIUL JN.
# LKR: LUCKEESARAI
# BRYA: BARHIYA
# DKGS: SIMARIA
# BJU: BARAUNI JN.
# BCA: BACHWARA JN.
# DSS: DALSINGH SAR
# NAZJ: NAZIRGANJ
# UJP: UJIARPUR
# SPJ: SAMASTIPUR J
# KPGM: KARPOORIGRAM
# KRBP: KHUDIRAM BOS
# DOL: DHOLI
# Train: Train MITHILA EXPR (MITHILA EXPR): HWH: HOWRAH JN. -> RXL: RAXAUL JN. with 42 stops
# Train: Train HOWRAH GAYA (HOWRAH GAYA): HWH: HOWRAH JN. -> GAYA: GAYA JN. with 33 stops
# Train: Train KAVI GURU EX (KAVI GURU EX): HWH: HOWRAH JN. -> AZ: AZIMGANJ JN. with 11 stops
# Train: Train HWH-KIR EXP (HWH-KIR EXP): HWH: HOWRAH JN. -> KIR: KATIHAR JN. with 49 stops
# AZ: AZIMGANJ JN.
# ACLE: AZIMGANJ  CI
# MPLR: MAHIPAL ROAD
# MGLE: MANIGRAM
# GALE: GANKAR
# JRLE: JANGIPUR ROA
# AHN: AHIRAN H
# SPLE: SUJNIPARA
# NILE: NIMTITA
# BDBP: BASUDEBPUR H
# DGLE: DHULIAN GANG
# SXP: SANKOPARA H
# NFK: NEW FARAKKA
# CMX: CHAMAGRAM
# KTJ: KHALTIPUR
# JMQ: JAMIRGHATA
# GZM: GOUR MALDA
# MLDT: MALDA TOWN
# SM: SAMSI
# BKRD: BHALUKA ROAD
# HCR: HARISHCHANDR
# KDPR: KUMEDPUR
# LAV: LABHA
# Train: Train HWH RXL EXPR (HWH RXL EXPR): HWH: HOWRAH JN. -> RXL: RAXAUL JN. with 19 stops
# JAJ: JHAJHA
# KIUL: KIUL JN.
# BJU: BARAUNI JN.
# DSS: DALSINGH SAR
# SPJ: SAMASTIPUR J
# Train: Train HWH SURI EXP (HWH SURI EXP): HWH: HOWRAH JN. -> SURI: SIURI with 6 stops
# BWN: BARDDHAMAN J
# BHP: BOLPUR
# PNE: PRANTIK
# Train: Train SURI HWH EXP (SURI HWH EXP): SURI: SIURI -> HWH: HOWRAH JN. with 6 stops
# Train: Train HWH JMP EXPR (HWH JMP EXPR): HWH: HOWRAH JN. -> JMP: JAMALPUR JN. with 21 stops
# Train: Train MUZAFFARPUR- (MUZAFFARPUR-): MFP: MUZAFFARPUR -> YPR: YESVANTPUR J with 35 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BALU: BALUGAN
# BAM: BERHAMPUR
# Train: Train KYQ-PURI  EX (KYQ-PURI  EX): KYQ: KAMAKHYA JN -> PURI: PURI with 26 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# PURI: PURI
# Train: Train HWH-KIR EXPR (HWH-KIR EXPR): HWH: HOWRAH JN. -> KIR: KATIHAR JN. with 11 stops
# MLDT: MALDA TOWN
# SM: SAMSI
# HCR: HARISHCHANDR
# KDPR: KUMEDPUR
# LAV: LABHA
# KIR: KATIHAR JN.
# Train: Train PAHARIA EXPR (PAHARIA EXPR): DGHA: DIGHA FS -> NJP: NEW JALPAIGU with 18 stops
# MLDT: MALDA TOWN
# BOE: BARSOI JN.
# KNE: KISHANGANJ
# Train: Train HWH-JDB EXPR (HWH-JDB EXPR): HWH: HOWRAH JN. -> JDB: JAGADALPUR with 48 stops
# MOU: MANOHARPUR
# BZR: BISRA
# BNDM: BONDAMUNDA J
# ROU: ROURKELA
# PPO: PANPOSH
# KLG: KALUNGA
# KXN: KANSBAHAL
# GP: RAJGANGPUR
# GPH: GARPOS
# BMB: BAMRA
# BEH: BAGDIHI
# JSG: JHARSUGUDA J
# RGL: RENGALI
# SBPD: SAMBALPUR RO
# SBP: SAMBALPUR JN
# HKG: HIRAKUND
# Train: Train HWH-VSGAMARA (HWH-VSGAMARA): HWH: HOWRAH JN. -> VSG: VASCO-DA-GAM with 44 stops
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BAM: BERHAMPUR
# PSA: PALASA
# CHE: SRIKAKULAM R
# Train: Train VSG HWH AMAR (VSG HWH AMAR): VSG: VASCO-DA-GAM -> HWH: HOWRAH JN. with 45 stops
# Train: Train SRIJAGANNATH (SRIJAGANNATH): HWH: HOWRAH JN. -> PURI: PURI with 20 stops
# KIS: KAPILAS ROAD
# CTC: CUTTACK JN.
# BRAG: BARANG JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# SIL: SAKHIGOPAL
# PURI: PURI
# Train: Train HWH-HTE KRII (HWH-HTE KRII): HWH: HOWRAH JN. -> HTE: HATIA with 17 stops
# TRAN: TORANG
# MURI: MURI
# TIS: TATISILWAI
# NKM: NAMKOM
# RNC: RANCHI
# HTE: HATIA
# Train: Train HWH NJP AC E (HWH NJP AC E): HWH: HOWRAH JN. -> NJP: NEW JALPAIGU with 8 stops
# MLDT: MALDA TOWN
# BOE: BARSOI JN.
# KNE: KISHANGANJ
# AUB: ALUABARI ROA
# NJP: NEW JALPAIGU
# Train: Train NJP HWH AC (NJP HWH AC): NJP: NEW JALPAIGU -> HWH: HOWRAH JN. with 8 stops
# Train: Train BLACKDIAMOND (BLACKDIAMOND): DHN: DHANBAD JN. -> HWH: HOWRAH JN. with 16 stops
# Train: Train NTSK - SBC S (NTSK - SBC S): NTSK: NEW TINSUKIA -> SBC: KRANTIVIRA S with 39 stops
# CTC: CUTTACK JN.
# BBS: BHUBANESWAR
# KUR: KHURDA ROAD
# BAM: BERHAMPUR
# Train: Train KARMABHOOMI (KARMABHOOMI): LTT: LOKMANYA TIL -> KYQ: KAMAKHYA JN with 27 stops
# MLDT: MALDA TOWN
# NJP: NEW JALPAIGU
# Train: Train HWH-SBP S/F (HWH-SBP S/F): HWH: HOWRAH JN. -> SBP: SAMBALPUR JN with 11 stops
# DNKL: DHENKANAL
# TLHD: TALCHER ROAD
# ANGL: ANGUL
# BONA: BOINDA
# RAIR: RAIRAKHOL
# SBP: SAMBALPUR JN
# Train: Train SNSI-HWH EXP (SNSI-HWH EXP): SNSI: SAI NAGAR SH -> HWH: HOWRAH JN. with 16 stops
# Train: Train DGHA -HWHKAN (DGHA -HWHKAN): DGHA: DIGHA FS -> HWH: HOWRAH JN. with 9 stops
# Train: Train CDAE-HWH LOC (CDAE-HWH LOC): CDAE: CHANDANPUR -> HWH: HOWRAH JN. with 14 stops
# Train: Train MSAE-HWH LOC (MSAE-HWH LOC): MSAE: MASAGRAM -> HWH: HOWRAH JN. with 24 stops
# Train: Train MSAE-HWH LOC (MSAE-HWH LOC): MSAE: MASAGRAM -> HWH: HOWRAH JN. with 24 stops
# Train: Train HWH-MSAELOCA (HWH-MSAELOCA): HWH: HOWRAH JN. -> MSAE: MASAGRAM with 24 stops
# Train: Train MSAE-HWH LOC (MSAE-HWH LOC): MSAE: MASAGRAM -> HWH: HOWRAH JN. with 22 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 28 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 29 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 29 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 26 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 30 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train HWH - BWN (C (HWH - BWN (C): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 29 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 29 stops
# Train: Train BWN-HWH(CHOR (BWN-HWH(CHOR): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 30 stops
# Train: Train SHE-HWH LOCA (SHE-HWH LOCA): SHE: SEORAPHULI J -> HWH: HOWRAH JN. with 10 stops
# Train: Train BRMH - HWH L (BRMH - HWH L): BRMH: BELURMATH -> HWH: HOWRAH JN. with 3 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH-BDC LOCA (HWH-BDC LOCA): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH - BDC LO (HWH - BDC LO): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH-BDC LOCA (HWH-BDC LOCA): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH-BDC LOCA (HWH-BDC LOCA): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC-HWH LOCA (BDC-HWH LOCA): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH-BDC LOCA (HWH-BDC LOCA): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train BDC LOCAL (BDC LOCAL): BDC: BANDEL JN. -> HWH: HOWRAH JN. with 17 stops
# Train: Train HWH-BDC LOCA (HWH-BDC LOCA): HWH: HOWRAH JN. -> BDC: BANDEL JN. with 17 stops
# Train: Train ANDOLAN LOCA (ANDOLAN LOCA): HWH: HOWRAH JN. -> SIU: SINGUR with 13 stops
# Train: Train SIU-HWH LOCA (SIU-HWH LOCA): SIU: SINGUR -> HWH: HOWRAH JN. with 13 stops
# Train: Train HWH - TAK LO (HWH - TAK LO): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train HWH-TAK LOCA (HWH-TAK LOCA): HWH: HOWRAH JN. -> TAK: TARAKESHWAR with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train TAK-HWH LOCA (TAK-HWH LOCA): TAK: TARAKESHWAR -> HWH: HOWRAH JN. with 21 stops
# Train: Train AMBG-HWH LOC (AMBG-HWH LOC): AMBG: ARAMBAG -> HWH: HOWRAH JN. with 23 stops
# Train: Train GOGT-HWH LOC (GOGT-HWH LOC): AMBG: ARAMBAG -> HWH: HOWRAH JN. with 23 stops
# Train: Train AMBG-HWH LOC (AMBG-HWH LOC): AMBG: ARAMBAG -> HWH: HOWRAH JN. with 23 stops
# Train: Train BWN - HWH LO (BWN - HWH LO): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops
# Train: Train BWN - HWH LO (BWN - HWH LO): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 22 stops
# Train: Train BWN - HWH LO (BWN - HWH LO): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 33 stops
# Train: Train BWN-HWH LOCA (BWN-HWH LOCA): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops
# Train: Train HWH - BWN LO (HWH - BWN LO): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 11 stops
# Train: Train BWN - HWH LO (BWN - HWH LO): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops
# Train: Train HWH-BWN LOCA (HWH-BWN LOCA): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 34 stops
# Train: Train BWN-HWH MAIN (BWN-HWH MAIN): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops
# Train: Train HWH-BWN LOCA (HWH-BWN LOCA): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 30 stops
# Train: Train BWN-HWH NON (BWN-HWH NON): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops
# Train: Train HWH-BWN MAIN (HWH-BWN MAIN): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 34 stops
# Train: Train HWH - BWN NO (HWH - BWN NO): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 34 stops
# Train: Train HWH - KATWA (HWH - KATWA): HWH: HOWRAH JN. -> KWAE: KATWA JN. with 29 stops
# Train: Train HWH - KATWA (HWH - KATWA): HWH: HOWRAH JN. -> KWAE: KATWA JN. with 41 stops
# Train: Train KWAE-HWH LOC (KWAE-HWH LOC): KWAE: KATWA JN. -> HWH: HOWRAH JN. with 40 stops
# Train: Train HLZ HWH LOCA (HLZ HWH LOCA): HLZ: HALDIA -> HWH: HOWRAH JN. with 26 stops
# Train: Train ULB-HWH SUB (ULB-HWH SUB): ULB: ULUBARIA -> HWH: HOWRAH JN. with 13 stops
# Train: Train HWH-MCA LOCA (HWH-MCA LOCA): HWH: HOWRAH JN. -> MCA: MECHEDA with 20 stops
# Train: Train HWH PKU LOCA (HWH PKU LOCA): HWH: HOWRAH JN. -> PKU: PANSKURA with 24 stops
# Train: Train HWH PKU LOCA (HWH PKU LOCA): HWH: HOWRAH JN. -> PKU: PANSKURA with 24 stops
# Train: Train HWH PKU LOCA (HWH PKU LOCA): HWH: HOWRAH JN. -> PKU: PANSKURA with 24 stops
# Train: Train PKU HWH LOCA (PKU HWH LOCA): PKU: PANSKURA -> HWH: HOWRAH JN. with 24 stops
# Train: Train HWH PKU LOCA (HWH PKU LOCA): HWH: HOWRAH JN. -> PKU: PANSKURA with 24 stops
# Train: Train PKU HWH LOCA (PKU HWH LOCA): PKU: PANSKURA -> HWH: HOWRAH JN. with 24 stops
# Train: Train HWH-PKU LOCA (HWH-PKU LOCA): HWH: HOWRAH JN. -> PKU: PANSKURA with 24 stops
# Train: Train PKU-HWH LOCA (PKU-HWH LOCA): PKU: PANSKURA -> HWH: HOWRAH JN. with 24 stops
# Train: Train KGP HWH  LOC (KGP HWH  LOC): KGP: KHARAGPUR -> HWH: HOWRAH JN. with 33 stops
# Train: Train KGP HWH LOCA (KGP HWH LOCA): KGP: KHARAGPUR -> HWH: HOWRAH JN. with 31 stops
# Train: Train KGP HWH LOCA (KGP HWH LOCA): KGP: KHARAGPUR -> HWH: HOWRAH JN. with 27 stops
# Train: Train MDN-HWH LOCA (MDN-HWH LOCA): MDN: MIDNAPORE -> HWH: HOWRAH JN. with 29 stops
# Train: Train MDN HWH LOCA (MDN HWH LOCA): MDN: MIDNAPORE -> HWH: HOWRAH JN. with 36 stops
# Train: Train MDN HWH LOCA (MDN HWH LOCA): MDN: MIDNAPORE -> HWH: HOWRAH JN. with 36 stops
# Train: Train HWH-MDN LOCA (HWH-MDN LOCA): HWH: HOWRAH JN. -> MDN: MIDNAPORE with 26 stops
# Train: Train MDN-HWH LOCA (MDN-HWH LOCA): MDN: MIDNAPORE -> HWH: HOWRAH JN. with 36 stops
# Train: Train HWH MDN LOCA (HWH MDN LOCA): HWH: HOWRAH JN. -> MDN: MIDNAPORE with 34 stops
# Train: Train HWH-AMZ LOCA (HWH-AMZ LOCA): HWH: HOWRAH JN. -> AMZ: AMTA with 21 stops
# Train: Train AMZ-HWH LOCA (AMZ-HWH LOCA): AMZ: AMTA -> HWH: HOWRAH JN. with 21 stops
# Train: Train JYG-HWH PASS (JYG-HWH PASS): JYG: JAYNAGAR -> HWH: HOWRAH JN. with 107 stops
# Train: Train HWH-MKA PASS (HWH-MKA PASS): HWH: HOWRAH JN. -> MKA: MOKAMA JN. with 53 stops
# VDS: VIDYASAGAR
# MNC: MADANKATA
# JRW: JORAMOW
# MDP: MADHUPUR JN.
# MUW: MATHURA PUR
# SNQ: SANKARPUR
# KBQ: KUMRABAD ROH
# JSME: JASIDIH JN.
# LHB: LAHABON HALT
# STL: SIMULTALA
# NRGO: NARGANJO HAL
# JAJ: JHAJHA
# DPX: DADPUR BH
# GHR: GIDHAUR
# CUX: CHAURA BH
# JMU: JAMUI
# BFM: BHALUI
# MNP: MANANPUR
# BSQP: BANSIPUR
# KIUL: KIUL JN.
# LKR: LUCKEESARAI
# MKB: MANKATHA
# BRYA: BARHIYA
# RDUM: RAMPUR DUMRA
# HTZ: HATHIDAH JN
# TALL: TALL JN.
# MKA: MOKAMA JN.
# Train: Train HWH  PURI  P (HWH  PURI  P): HWH: HOWRAH JN. -> PURI: PURI with 91 stops
# NGRD: NILGIRI ROAD
# KHF: KHANTAPARA
# PNPN: PANPANA PH
# BNBR: BAHANAGA BAZ
# SORO: SORO
# SZZ: SABIRA
# MKO: MARKONA
# RNTL: RANITAL
# BHC: BHADRAKH
# BUDR: BAUDPUR
# KPLD: KAPALI ROAD
# KED: KENDUAPADA
# MZZ: MANJURI ROAD
# DLPT: DULAKHAPATNA
# BTV: BAITARANI RO
# KRIH: KORAI HALT
# JJKR: JAJPUR KEONJ
# JKPR: JAKHAPURA JN
# BRMI: BRAHMANI
# JEN: JENAPUR
# NGMP: NEW GARH MAD
# HDS: HARIDAS PUR
# DNM: DHANMANDAL
# BRTG: BARITHEN GAR
# BYY: BYREE
# SJDR: SRI JHADESHW
# KIS: KAPILAS ROAD
# SQQ: SALAGAON
# CBT: CHAR BATIA
# BDPG: BADA PADAGAO
# GJTA: GURUDIJHATIA
# MZY: MACHAPUR
# RQP: RADHA KISHOR
# GHNH: GHANTIKAL NI
# SPSR: SARPESWAR P.
# NQR: NARAJ MARATH
# BRAG: BARANG JN.
# MCS: MANCHESWAR
# BBS: BHUBANESWAR
# LGTR: LINGARAJ TEM
# RTN: RETANG
# KUR: KHURDA ROAD
# HPGM: HARIPUR GRAM
# Train: Train HWH-ADRA CKP (HWH-ADRA CKP): HWH: HOWRAH JN. -> CKP: CHAKARADHARP with 45 stops
# ADRA: ADRA
# GRB: GARH-DHRUBBE
# ANR: ANARA
# BGA: BAGALIA
# KSU: KUSTAUR
# CHRA: CHHARRA
# PRR: PURULIA JN.
# TAO: TAMNA
# KTD: KANTADIH
# URMA: URMA
# BBM: BARABHUM
# BRMD: BIRAMDIH
# NIM: NIMDIH
# CNI: CHANDIL JN.
# MIK: MANIKUI
# KZU: KUNKI BH
# KND: KANDRA
# SINI: SINI JN
# MMV: MAHALI MARUP
# RKSN: RAJKHARSAWAN
# BRM: BARABAMBO
# CKP: CHAKARADHARP
# Train: Train HWH- BWN M/L (HWH- BWN M/L): HWH: HOWRAH JN. -> BWN: BARDDHAMAN J with 3 stops
# Train: Train BWN - HWH LO (BWN - HWH LO): BWN: BARDDHAMAN J -> HWH: HOWRAH JN. with 34 stops

# %%
# Do the same using sql
import pandas as pd
timetable = pd.read_csv("./train_details_2017.csv")
# Out:
# /tmp/ipykernel_1557920/82050991.py:3: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   timetable = pd.read_csv("./train_details_2017.csv")

# %%
# Filter evening trains
evening_trains = timetable[
    (timetable['Station Code'] == 'HWH') &
    (timetable['Departure Time'].between('19:00:00', '22:00:00'))
][['Train No', 'Departure Time']]

# Filter morning stations
morning_stations = timetable[
    timetable['Arrival time'].between('06:00:00', '10:00:00')
][['Train No', 'Station Code', 'Arrival time']]

# Merge evening trains and morning stations
trains_with_travel_time = evening_trains.merge(
    morning_stations, on='Train No', suffixes=('_start', '_end')
)

# %%
# Calculate travel time and add a day if needed
trains_with_travel_time['travel_time'] = (
    pd.to_timedelta(trains_with_travel_time['Arrival time']) -
    pd.to_timedelta(trains_with_travel_time['Departure Time'])
)
trains_with_travel_time.loc[
    trains_with_travel_time['travel_time'] < pd.Timedelta(0),
    'travel_time'
] += pd.Timedelta(days=1)

# Convert travel time to hours
trains_with_travel_time['travel_time'] /= pd.Timedelta(hours=1)

# Filter stations with travel time between 6 and 10 hours
result = trains_with_travel_time['Station Code'].drop_duplicates().sort_values()
# result = trains_with_travel_time[
#     trains_with_travel_time['travel_time'].between(6, 10)
# ]['Station Code'].drop_duplicates().sort_values()

# Print the result
print(len(result))
# Out:
# 133

# %%
import pandas as pd
import sqlite3

# Read the CSV file
timetable = pd.read_csv('train_details_2017.csv')

# Create an in-memory SQLite database
connection = sqlite3.connect(':memory:')

# Write the pandas DataFrame to the SQLite database
timetable.to_sql('timetable', connection, if_exists='replace', index=False)
# Out:
# /tmp/ipykernel_1557920/3212819658.py:5: DtypeWarning: Columns (0,2,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   timetable = pd.read_csv('train_details_2017.csv')
# 186124

# %%
# Define the SQL query
sql_query = """
WITH evening_trains AS (
  SELECT "Train No", "Departure Time" AS start_time, SEQ AS start_seq
  FROM timetable
  WHERE "Station Code" = 'HWH'
    AND "Departure Time" BETWEEN '19:00:00' AND '22:00:00'
),
morning_stations AS (
  SELECT "Train No", "Station Code", "Arrival Time" AS end_time, SEQ AS end_seq
  FROM timetable
  WHERE "Arrival Time" BETWEEN '06:00:00' AND '10:00:00'
),
trains_with_travel_time AS (
  SELECT et."Train No", et.start_time, ms."Station Code", ms.end_time,
    (strftime('%s', ms.end_time) - strftime('%s', et.start_time) +
      (CASE WHEN ms.end_time < et.start_time THEN 86400 ELSE 0 END)) / 3600.0 AS travel_time
  FROM morning_stations ms
  JOIN evening_trains et ON ms."Train No" = et."Train No" and ms.end_seq > et.start_seq
)

SELECT DISTINCT "Station Code"
FROM trains_with_travel_time
WHERE travel_time BETWEEN 6 AND 10
ORDER BY "Station Code";
"""

# Execute the SQL query and store the result in a pandas DataFrame
result = pd.read_sql_query(sql_query, connection)

# Close the SQLite connection
connection.close()

# Print the result
print(result)
# Out:
#    Station Code
# 0           AKN
# 1          AUBR
# 2          BAND
# 3           BBU
# 4           BCA
# 5           BEH
# 6           BJU
# 7          BLQR
# 8           BMB
# 9           BSP
# 10          BUP
# 11          CMX
# 12          CPH
# 13         DKGS
# 14          DOS
# 15          DVL
# 16          DWO
# 17           GP
# 18          GPH
# 19          GZM
# 20         HLDD
# 21          JMP
# 22          JMQ
# 23          KIR
# 24          KTJ
# 25          KYN
# 26         MLDT
# 27          NFK
# 28           NK
# 29         PUNE
# 30            R
# 31         RAIR
# 32          RIG
# 33         RJPB
# 34          ROU
# 35         RUPC
# 36          SEB
# 37          SGG
# 38          SSM
